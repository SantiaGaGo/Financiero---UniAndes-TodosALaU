# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiaGaGo/Financiero---UniAndes-TodosALaU/blob/main/Se%C3%B1alesDeTrading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files
import matplotlib.pyplot as plt
import pandas_datareader as pdr

# %%
df= pdr.get_data_fred('DCOILBRENTEU', start='2016-01-01', end='2021-01-01')
df= df.dropna()
df.columns=['Close']
df
# Out:
#             Close
# DATE
# 2016-01-04  36.28
# 2016-01-05  35.56
# 2016-01-06  33.89
# 2016-01-07  33.57
# 2016-01-08  31.67
# ...           ...
# 2020-12-24  50.88
# 2020-12-28  50.88
# 2020-12-29  50.44
# 2020-12-30  50.74
# 2020-12-31  51.22
#
# [1275 rows x 1 columns]

# %%
#EMA 5 dias
df['EMA_short']= df['Close'].ewm(span=5, adjust=False).mean()

#EMA 20 dias
df['EMA_long']= df['Close'].ewm(span=20, adjust=False).mean()

df
# Out:
#             Close  EMA_short   EMA_long
# DATE
# 2016-01-04  36.28  36.280000  36.280000
# 2016-01-05  35.56  36.040000  36.211429
# 2016-01-06  33.89  35.323333  35.990340
# 2016-01-07  33.57  34.738889  35.759832
# 2016-01-08  31.67  33.715926  35.370324
# ...           ...        ...        ...
# 2020-12-24  50.88  50.792761  49.228966
# 2020-12-28  50.88  50.821840  49.386208
# 2020-12-29  50.44  50.694560  49.486569
# 2020-12-30  50.74  50.709707  49.605943
# 2020-12-31  51.22  50.879805  49.759663
#
# [1275 rows x 3 columns]

# %%
plt.figure(figsize=(16,8))
plt.title('EMA 5 dias & EMA 20 dias')
plt.plot(df['Close'])
plt.plot(df['EMA_short'], color ='orange', alpha=0.4)
plt.plot(df['EMA_long'], color ='red',alpha=0.4)
plt.xlabel('Fecha')
plt.ylabel('USD $$$')
plt.legend(['Close', 'EMA_short','EMA_long'], loc='lower right')
plt.show()

# %%
#Numero de datos
N= len(df)

#lista de señales
#-1 vender
# 0 mantener
#1 comprar
signals=[0]

for i in range(1,N):
  short  =df['EMA_short'][i]
  long  =df['EMA_long'][i]

  p_short=df['EMA_short'][i-1]
  p_long=df['EMA_long'][i-1]

  if p_short < p_long and short >= long:
    signals.append(1)
  elif p_short > p_long and short <= long:
    signals.append(-1)
  else:
    signals.append(0)

df['signals']= signals
df
# Out:
#             Close  EMA_short   EMA_long  signals
# DATE
# 2016-01-04  36.28  36.280000  36.280000        0
# 2016-01-05  35.56  36.040000  36.211429        0
# 2016-01-06  33.89  35.323333  35.990340        0
# 2016-01-07  33.57  34.738889  35.759832        0
# 2016-01-08  31.67  33.715926  35.370324        0
# ...           ...        ...        ...      ...
# 2020-12-24  50.88  50.792761  49.228966        0
# 2020-12-28  50.88  50.821840  49.386208        0
# 2020-12-29  50.44  50.694560  49.486569        0
# 2020-12-30  50.74  50.709707  49.605943        0
# 2020-12-31  51.22  50.879805  49.759663        0
#
# [1275 rows x 4 columns]

# %%
df['Buy']= np.where(df['signals']==1, df['Close'], np.nan)
df['Sell']= np.where(df['signals']==-1, df['Close'], np.nan)
df
# Out:
#             Close  EMA_short   EMA_long  signals  Buy  Sell
# DATE
# 2016-01-04  36.28  36.280000  36.280000        0  NaN   NaN
# 2016-01-05  35.56  36.040000  36.211429        0  NaN   NaN
# 2016-01-06  33.89  35.323333  35.990340        0  NaN   NaN
# 2016-01-07  33.57  34.738889  35.759832        0  NaN   NaN
# 2016-01-08  31.67  33.715926  35.370324        0  NaN   NaN
# ...           ...        ...        ...      ...  ...   ...
# 2020-12-24  50.88  50.792761  49.228966        0  NaN   NaN
# 2020-12-28  50.88  50.821840  49.386208        0  NaN   NaN
# 2020-12-29  50.44  50.694560  49.486569        0  NaN   NaN
# 2020-12-30  50.74  50.709707  49.605943        0  NaN   NaN
# 2020-12-31  51.22  50.879805  49.759663        0  NaN   NaN
#
# [1275 rows x 6 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Close'], alpha=0.4, label='Precios')
plt.scatter(df.index, df['Buy'], color= 'green', marker='^', label= 'Compra')
plt.scatter(df.index, df['Sell'], color= 'red', marker='v', label='Venta')
plt.title('Señales de compra y venta')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.legend(loc='upper left')
plt.show()

# %%
# backtesting
N= len(df)
equity=[100]

TP=0.03
SL=0.01

pos= 0
for i in range (1,N):
  equity.append(equity[i-1])

  if pos == 1 :
    if df['Close'][i] >= price*(1+TP):
      pos=0
      equity[i]*= (1+TP)

    elif df['Close'][i] <= price*(1-SL):
      pos=0
      equity[i]*= (1-SL)

  elif pos ==-1:

    if df['Close'][i] <= price*(1-TP):
      pos=0
      equity[i]*= (1+TP)

    elif df['Close'][i] >= price*(1+SL):
      pos=0
      equity[i]*= (1-SL)

  else:

    if df['signals'][i] != 0:
      pos =df['signals'][i]
      price= df['Close'][i]

df['equity']= equity

# %%
df
# Out:
#             Close  EMA_short   EMA_long  signals  Buy  Sell      equity
# DATE
# 2016-01-04  36.28  36.280000  36.280000        0  NaN   NaN  100.000000
# 2016-01-05  35.56  36.040000  36.211429        0  NaN   NaN  100.000000
# 2016-01-06  33.89  35.323333  35.990340        0  NaN   NaN  100.000000
# 2016-01-07  33.57  34.738889  35.759832        0  NaN   NaN  100.000000
# 2016-01-08  31.67  33.715926  35.370324        0  NaN   NaN  100.000000
# ...           ...        ...        ...      ...  ...   ...         ...
# 2020-12-24  50.88  50.792761  49.228966        0  NaN   NaN  122.044183
# 2020-12-28  50.88  50.821840  49.386208        0  NaN   NaN  122.044183
# 2020-12-29  50.44  50.694560  49.486569        0  NaN   NaN  122.044183
# 2020-12-30  50.74  50.709707  49.605943        0  NaN   NaN  122.044183
# 2020-12-31  51.22  50.879805  49.759663        0  NaN   NaN  122.044183
#
# [1275 rows x 7 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(df['equity'])
plt.title('Estrategia de medias moviles exponenciales')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.show()

# %%
ret =np.log(df['equity']).diff().mean()
ret*=252
#ret

vol=np.log(df['equity']).diff().std()
vol *= np.sqrt(252)

rf=0.01

sharpe_ratio= (ret-rf)/vol
sharpe_ratio
# Out:
# 0.4519606496376969

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.1.81-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed requests-2.28.1 yfinance-0.1.81

# %%
import yfinance as yfin

# %%
df2= yfin.download('^GSPC', start='2016-01-01', end='2021-01-01')
df2
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-01-04  2038.199951  2038.199951  1989.680054  2012.660034  2012.660034
# 2016-01-05  2013.780029  2021.939941  2004.170044  2016.709961  2016.709961
# 2016-01-06  2011.709961  2011.709961  1979.050049  1990.260010  1990.260010
# 2016-01-07  1985.319946  1985.319946  1938.829956  1943.089966  1943.089966
# 2016-01-08  1945.969971  1960.400024  1918.459961  1922.030029  1922.030029
# ...                 ...          ...          ...          ...          ...
# 2020-12-24  3694.030029  3703.820068  3689.320068  3703.060059  3703.060059
# 2020-12-28  3723.030029  3740.510010  3723.030029  3735.360107  3735.360107
# 2020-12-29  3750.010010  3756.120117  3723.310059  3727.040039  3727.040039
# 2020-12-30  3736.189941  3744.629883  3730.209961  3732.040039  3732.040039
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
#
#                 Volume
# Date
# 2016-01-04  4304880000
# 2016-01-05  3706620000
# 2016-01-06  4336660000
# 2016-01-07  5076590000
# 2016-01-08  4664940000
# ...                ...
# 2020-12-24  1885090000
# 2020-12-28  3527460000
# 2020-12-29  3387030000
# 2020-12-30  3145200000
# 2020-12-31  3172510000
#
# [1259 rows x 6 columns]

# %%
df2['equity']=(100/df2['Close'][0]*df2['Close'])
df2
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-01-04  2038.199951  2038.199951  1989.680054  2012.660034  2012.660034
# 2016-01-05  2013.780029  2021.939941  2004.170044  2016.709961  2016.709961
# 2016-01-06  2011.709961  2011.709961  1979.050049  1990.260010  1990.260010
# 2016-01-07  1985.319946  1985.319946  1938.829956  1943.089966  1943.089966
# 2016-01-08  1945.969971  1960.400024  1918.459961  1922.030029  1922.030029
# ...                 ...          ...          ...          ...          ...
# 2020-12-24  3694.030029  3703.820068  3689.320068  3703.060059  3703.060059
# 2020-12-28  3723.030029  3740.510010  3723.030029  3735.360107  3735.360107
# 2020-12-29  3750.010010  3756.120117  3723.310059  3727.040039  3727.040039
# 2020-12-30  3736.189941  3744.629883  3730.209961  3732.040039  3732.040039
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
#
#                 Volume      equity
# Date
# 2016-01-04  4304880000  100.000000
# 2016-01-05  3706620000  100.201223
# 2016-01-06  4336660000   98.887044
# 2016-01-07  5076590000   96.543377
# 2016-01-08  4664940000   95.497004
# ...                ...         ...
# 2020-12-24  1885090000  183.988354
# 2020-12-28  3527460000  185.593197
# 2020-12-29  3387030000  185.179811
# 2020-12-30  3145200000  185.428238
# 2020-12-31  3172510000  186.622182
#
# [1259 rows x 7 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(df['equity'], label='Estrategia de medias moviles exponenciales')
plt.plot(df2['equity'], label= 'Portafolio S&P500')
plt.title('Comparacion estrategias')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.legend(loc= 'lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-78a071f7666a> in <module>
# ----> 1 plt.figure(figsize=(16,8))
#       2 plt.plot(df['equity'], label='Estrategia de medias moviles exponenciales')
#       3 plt.plot(df2['equity'], label= 'Portafolio S&P500')
#       4 plt.title('Comparacion estrategias')
#       5 plt.xlabel('Fecha')
#
# NameError: name 'plt' is not defined

# %%
ret =np.log(df2['equity']).diff().mean()
ret*=252
#ret

vol=np.log(df2['equity']).diff().std()
vol *= np.sqrt(252)

rf=0.01

sharpe_ratio= (ret-rf)/vol
sharpe_ratio
# Out:
# 0.59481054922144
